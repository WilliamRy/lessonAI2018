# %%
import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer,LabelEncoder
from sklearn.base import BaseEstimator, TransformerMixin

# %%
#读取数据
train = pd.read_csv('D:/Anconda/data/data/train.csv', index_col = 'index')
test = pd.read_csv('D:/Anconda/data/data/test.csv', index_col = 'index')
submit = pd.read_csv('D:/Anconda/data/data/submit_sample.csv', index_col = 'index')

# %%
#清洗数据,由于树模型的特点，所以一般不用onehot，xgboost也能够处理缺失值，所以只需把非数值类型化成数值类型即可
class RobustLabelEncoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.classes_ = []
        self.set_classes_ = None
        self.unseen_tag = 'unseen'
    def fit(self, list_):
        self.set_classes_ = set(list_)
        self.classes_ = list(self.set_classes_) + [self.unseen_tag]
        return self
    def transform(self, list_):
        list_ = [obj if obj in self.set_classes_ else self.unseen_tag for obj in list_]
        dct = dict(zip(self.classes_, range(len(self.classes_))))
        res = [dct[obj] for obj in list_]
        return res
def clean_nul(data):
    if data==None:
        data = 'cd'
    else:
        data = data
    return data
train['c'] = train['c'].apply(clean_nul)
test['c'] = test['c'].apply(clean_nul)
df_train = train.merge(test,how='left')
rle_c = RobustLabelEncoder()
rle_c.fit_transform(df_train['c'])
rle_d = RobustLabelEncoder()
rle_d.fit_transform(df_train['d'])
train['c'] = rle_c.transform(train['c'])
train['d'] = rle_d.transform(train['d'])
test['c'] = rle_c.transform(test['c'])
test['d'] = rle_d.transform(test['d'])

Y_train = np.array(train['label'])
y_mean = np.mean(Y_train)
train = train.drop(['level_0','label'],axis=1)
test_index = test['level_0']
test = test.drop(['level_0'],axis=1)

# %%
test.head()
# Out:
#               a     b  c  d
# index
# 1024   1.092965  99.0  9  5
# 1025   1.086392  97.0  6  4
# 1026   2.582640  35.0  9  5
# 1027   1.044559  18.0  3  1
# 1028   2.267531  56.0  2  3

# %%
#modeling
xgb_params = {
    'eta': 0.007,
    'max_depth': 5,
    'subsample': 0.60,
    'objective': 'reg:logistic',
    'eval_metric': 'error',
    'lambda': 5.0,
    'alpha': 0.65,
    'colsample_bytree': 0.5,
  #  'base_score': y_mean,
    'silent': 1
}
dtrain = xgb.DMatrix(train, Y_train)
dtest = xgb.DMatrix(test)

early_stopping_rounds = round( 1.5/ xgb_params['eta'] )
num_boost_rounds = round( 20 / xgb_params['eta'] )
# cross-validation
cv_result = xgb.cv(xgb_params, 
                   dtrain, 
                   nfold=5,
                   num_boost_round=num_boost_rounds,
                   early_stopping_rounds=early_stopping_rounds,
                   verbose_eval=10, 
                   show_stdv=False
                  )
num_boost_rounds = len(cv_result)
print(num_boost_rounds)
# train model
model = xgb.train(dict(xgb_params, silent=1), dtrain, num_boost_round=num_boost_rounds)
pred = model.predict(dtest)
y_pred=[]

for i,predict in enumerate(pred):
    y_pred.append(str(round(predict,4)))

y_pred=np.array(y_pred)

    
#
# Out:
# [0]	train-error:0.343414	test-error:0.413658
# [10]	train-error:0.190975	test-error:0.284878
# [20]	train-error:0.162439	test-error:0.276098
# [30]	train-error:0.146585	test-error:0.246829
# [40]	train-error:0.149512	test-error:0.241951
# [50]	train-error:0.140244	test-error:0.230244
# [60]	train-error:0.139512	test-error:0.232195
# [70]	train-error:0.135122	test-error:0.22439
# [80]	train-error:0.126585	test-error:0.223415
# [90]	train-error:0.127317	test-error:0.227317
# [100]	train-error:0.12561	test-error:0.216585
# [110]	train-error:0.122195	test-error:0.217561
# [120]	train-error:0.116585	test-error:0.213658
# [130]	train-error:0.117317	test-error:0.209756
# [140]	train-error:0.117317	test-error:0.21561
# [150]	train-error:0.114878	test-error:0.208781
# [160]	train-error:0.110488	test-error:0.203902
# [170]	train-error:0.108049	test-error:0.203902
# [180]	train-error:0.105854	test-error:0.199024
# [190]	train-error:0.10561	test-error:0.193171
# [200]	train-error:0.105366	test-error:0.197073
# [210]	train-error:0.105122	test-error:0.197073
# [220]	train-error:0.102195	test-error:0.193171
# [230]	train-error:0.0995122	test-error:0.193171
# [240]	train-error:0.0982928	test-error:0.196098
# [250]	train-error:0.0995122	test-error:0.193171
# [260]	train-error:0.099756	test-error:0.192195
# [270]	train-error:0.096829	test-error:0.187317
# [280]	train-error:0.094878	test-error:0.186342
# [290]	train-error:0.0931706	test-error:0.18439
# [300]	train-error:0.0926828	test-error:0.188293
# [310]	train-error:0.0936586	test-error:0.186342
# [320]	train-error:0.0953658	test-error:0.18439
# [330]	train-error:0.0907316	test-error:0.18439
# [340]	train-error:0.0897558	test-error:0.18439
# [350]	train-error:0.089024	test-error:0.187317
# [360]	train-error:0.0892682	test-error:0.186342
# [370]	train-error:0.0878048	test-error:0.18439
# [380]	train-error:0.0892684	test-error:0.185366
# [390]	train-error:0.0885364	test-error:0.182439
# [400]	train-error:0.087317	test-error:0.182439
# [410]	train-error:0.0860976	test-error:0.178537
# [420]	train-error:0.0858534	test-error:0.181464
# [430]	train-error:0.0846338	test-error:0.18439
# [440]	train-error:0.0836584	test-error:0.181464
# [450]	train-error:0.0836584	test-error:0.178537
# [460]	train-error:0.0819512	test-error:0.178537
# [470]	train-error:0.0795122	test-error:0.181464
# [480]	train-error:0.0780486	test-error:0.178537
# [490]	train-error:0.0760974	test-error:0.17561
# [500]	train-error:0.0751218	test-error:0.174634
# [510]	train-error:0.0758536	test-error:0.174634
# [520]	train-error:0.0743902	test-error:0.176586
# [530]	train-error:0.0736584	test-error:0.171708
# [540]	train-error:0.0734146	test-error:0.172683
# [550]	train-error:0.0724388	test-error:0.168781
# [560]	train-error:0.0719514	test-error:0.166829
# [570]	train-error:0.0719514	test-error:0.163903
# [580]	train-error:0.0712196	test-error:0.162927
# [590]	train-error:0.07	test-error:0.164878
# [600]	train-error:0.0695122	test-error:0.165854
# [610]	train-error:0.069756	test-error:0.163903
# [620]	train-error:0.0675612	test-error:0.163902
# [630]	train-error:0.0670732	test-error:0.162927
# [640]	train-error:0.0651222	test-error:0.162927
# [650]	train-error:0.0660976	test-error:0.162927
# [660]	train-error:0.0651218	test-error:0.160976
# [670]	train-error:0.0641466	test-error:0.162927
# [680]	train-error:0.0639024	test-error:0.160976
# [690]	train-error:0.0636586	test-error:0.159024
# [700]	train-error:0.0621952	test-error:0.158049
# [710]	train-error:0.0607316	test-error:0.159024
# [720]	train-error:0.0592684	test-error:0.157073
# [730]	train-error:0.0590246	test-error:0.158049
# [740]	train-error:0.0585368	test-error:0.155122
# [750]	train-error:0.0590246	test-error:0.154146
# [760]	train-error:0.0590246	test-error:0.149268
# [770]	train-error:0.0585366	test-error:0.149268
# [780]	train-error:0.0575612	test-error:0.148293
# [790]	train-error:0.0570734	test-error:0.147317
# [800]	train-error:0.0575612	test-error:0.145366
# [810]	train-error:0.0575612	test-error:0.14439
# [820]	train-error:0.0563416	test-error:0.139512
# [830]	train-error:0.0560978	test-error:0.137561
# [840]	train-error:0.05561	test-error:0.136585
# [850]	train-error:0.055854	test-error:0.137561
# [860]	train-error:0.0560978	test-error:0.138537
# [870]	train-error:0.055366	test-error:0.139512
# [880]	train-error:0.0539026	test-error:0.139512
# [890]	train-error:0.0534148	test-error:0.137561
# [900]	train-error:0.0534148	test-error:0.134634
# [910]	train-error:0.0531708	test-error:0.134634
# [920]	train-error:0.052439	test-error:0.134634
# [930]	train-error:0.052195	test-error:0.134634
# [940]	train-error:0.0521952	test-error:0.132683
# [950]	train-error:0.0517074	test-error:0.132683
# [960]	train-error:0.0509758	test-error:0.132683
# [970]	train-error:0.050244	test-error:0.132683
# [980]	train-error:0.050244	test-error:0.132683
# [990]	train-error:0.0492682	test-error:0.132683
# [1000]	train-error:0.0487802	test-error:0.131707
# [1010]	train-error:0.0482926	test-error:0.129756
# [1020]	train-error:0.0478048	test-error:0.129756
# [1030]	train-error:0.0473168	test-error:0.129756
# [1040]	train-error:0.0473168	test-error:0.130732
# [1050]	train-error:0.0475608	test-error:0.129756
# [1060]	train-error:0.0482928	test-error:0.127805
# [1070]	train-error:0.047561	test-error:0.128781
# [1080]	train-error:0.047317	test-error:0.127805
# [1090]	train-error:0.0470732	test-error:0.126829
# [1100]	train-error:0.0470732	test-error:0.125854
# [1110]	train-error:0.047561	test-error:0.125854
# [1120]	train-error:0.0468292	test-error:0.125854
# [1130]	train-error:0.0468292	test-error:0.122927
# [1140]	train-error:0.0465854	test-error:0.123902
# [1150]	train-error:0.046585	test-error:0.124878
# [1160]	train-error:0.0463414	test-error:0.122927
# [1170]	train-error:0.0456096	test-error:0.122927
# [1180]	train-error:0.044878	test-error:0.121951
# [1190]	train-error:0.045122	test-error:0.12
# [1200]	train-error:0.0443902	test-error:0.12
# [1210]	train-error:0.0441462	test-error:0.12
# [1220]	train-error:0.0441462	test-error:0.12
# [1230]	train-error:0.0441462	test-error:0.119024
# [1240]	train-error:0.0436582	test-error:0.119024
# [1250]	train-error:0.0436584	test-error:0.119024
# [1260]	train-error:0.0434144	test-error:0.119024
# [1270]	train-error:0.0436584	test-error:0.119024
# [1280]	train-error:0.0434144	test-error:0.119024
# [1290]	train-error:0.0429264	test-error:0.119024
# [1300]	train-error:0.0431704	test-error:0.12
# [1310]	train-error:0.0426828	test-error:0.120976
# [1320]	train-error:0.0424386	test-error:0.12
# [1330]	train-error:0.0414632	test-error:0.12
# [1340]	train-error:0.0414632	test-error:0.119024
# [1350]	train-error:0.041707	test-error:0.119024
# [1360]	train-error:0.042195	test-error:0.118049
# [1370]	train-error:0.0407314	test-error:0.118049
# [1380]	train-error:0.0404878	test-error:0.118049
# [1390]	train-error:0.0402436	test-error:0.118049
# [1400]	train-error:0.0399998	test-error:0.117073
# [1410]	train-error:0.0399996	test-error:0.116097
# [1420]	train-error:0.0402438	test-error:0.116097
# [1430]	train-error:0.0402436	test-error:0.115122
# [1440]	train-error:0.0399998	test-error:0.116097
# [1450]	train-error:0.0395122	test-error:0.116097
# [1460]	train-error:0.0395122	test-error:0.116097
# [1470]	train-error:0.0380488	test-error:0.116097
# [1480]	train-error:0.0382926	test-error:0.116097
# [1490]	train-error:0.0380488	test-error:0.116097
# [1500]	train-error:0.0380488	test-error:0.114146
# [1510]	train-error:0.037805	test-error:0.113171
# [1520]	train-error:0.037805	test-error:0.114146
# [1530]	train-error:0.037317	test-error:0.114146
# [1540]	train-error:0.037073	test-error:0.114146
# [1550]	train-error:0.036829	test-error:0.115122
# [1560]	train-error:0.0368292	test-error:0.115122
# [1570]	train-error:0.0373168	test-error:0.114146
# [1580]	train-error:0.0363414	test-error:0.114146
# [1590]	train-error:0.0363414	test-error:0.114146
# [1600]	train-error:0.0363414	test-error:0.114146
# [1610]	train-error:0.0360976	test-error:0.112195
# [1620]	train-error:0.0353658	test-error:0.113171
# [1630]	train-error:0.034634	test-error:0.112195
# [1640]	train-error:0.0341462	test-error:0.112195
# [1650]	train-error:0.0336584	test-error:0.112195
# [1660]	train-error:0.0334146	test-error:0.112195
# [1670]	train-error:0.0334146	test-error:0.111219
# [1680]	train-error:0.0343902	test-error:0.111219
# [1690]	train-error:0.034634	test-error:0.111219
# [1700]	train-error:0.0343902	test-error:0.110244
# [1710]	train-error:0.03439	test-error:0.110244
# [1720]	train-error:0.0341462	test-error:0.111219
# [1730]	train-error:0.0341462	test-error:0.110244
# [1740]	train-error:0.0341462	test-error:0.108293
# [1750]	train-error:0.0339024	test-error:0.108293
# [1760]	train-error:0.0331706	test-error:0.108293
# [1770]	train-error:0.0336584	test-error:0.109268
# [1780]	train-error:0.0334144	test-error:0.109268
# [1790]	train-error:0.0331706	test-error:0.109268
# [1800]	train-error:0.0331704	test-error:0.108293
# [1810]	train-error:0.0329266	test-error:0.108293
# [1820]	train-error:0.0329266	test-error:0.109268
# [1830]	train-error:0.032195	test-error:0.109268
# [1840]	train-error:0.032195	test-error:0.109268
# [1850]	train-error:0.0319512	test-error:0.107317
# [1860]	train-error:0.0319512	test-error:0.108293
# [1870]	train-error:0.0312196	test-error:0.108293
# [1880]	train-error:0.0312196	test-error:0.108293
# [1890]	train-error:0.0312196	test-error:0.107317
# [1900]	train-error:0.0309756	test-error:0.108293
# [1910]	train-error:0.0309758	test-error:0.108293
# [1920]	train-error:0.0304878	test-error:0.108293
# [1930]	train-error:0.0304878	test-error:0.108293
# [1940]	train-error:0.030244	test-error:0.106341
# [1950]	train-error:0.0309756	test-error:0.106341
# [1960]	train-error:0.0302438	test-error:0.105366
# [1970]	train-error:0.03	test-error:0.105366
# [1980]	train-error:0.03	test-error:0.10439
# [1990]	train-error:0.0295122	test-error:0.10439
# [2000]	train-error:0.0295122	test-error:0.10439
# [2010]	train-error:0.0292684	test-error:0.103415
# [2020]	train-error:0.029756	test-error:0.10439
# [2030]	train-error:0.029756	test-error:0.10439
# [2040]	train-error:0.0290242	test-error:0.10439
# [2050]	train-error:0.0290244	test-error:0.10439
# [2060]	train-error:0.0295122	test-error:0.10439
# [2070]	train-error:0.0280488	test-error:0.10439
# [2080]	train-error:0.027805	test-error:0.10439
# [2090]	train-error:0.0282926	test-error:0.10439
# [2100]	train-error:0.0280488	test-error:0.10439
# [2110]	train-error:0.027561	test-error:0.10439
# [2120]	train-error:0.0270732	test-error:0.10439
# [2130]	train-error:0.0270732	test-error:0.10439
# [2140]	train-error:0.0268292	test-error:0.10439
# [2150]	train-error:0.0268292	test-error:0.10439
# [2160]	train-error:0.0260974	test-error:0.10439
# [2170]	train-error:0.0258536	test-error:0.10439
# [2180]	train-error:0.0253658	test-error:0.10439
# [2190]	train-error:0.0253658	test-error:0.10439
# [2200]	train-error:0.025122	test-error:0.10439
# 1988
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-a01cfe97561b> in <module>()
#      38 y_pred=np.array(y_pred)
#      39 for i in y_pred:
# ---> 40     if i>0.5:
#      41         y_pred[i]=1
#      42     else:
#
# TypeError: '>' not supported between instances of 'numpy.str_' and 'float'

# %%
#输出
for j,i in enumerate(y_pred):
    if float(i)>0.5:
        y_pred[j]=1
    else:
        y_pred[j]=0
output = pd.DataFrame({'index':test_index,'label':y_pred})
output.to_csv('D:/Anconda/data/data/11749009.csv',index=False)
